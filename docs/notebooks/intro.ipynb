# %% [markdown]
# ---
# tags: [notebook, guide]
# ---

# %% [markdown]
# # Demo Notebook
# This notebook is rendered in the Class Wiki via **mkdocs-jupyter**.

# %%
import math
print(sum(i*i for i in range(10)))

# %% [markdown]
# ## Next steps
# - Add your own notebooks under `docs/notebooks/`.
# - Update `mkdocs.yml` to include them in the nav.
